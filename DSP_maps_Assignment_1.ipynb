# %%
import folium
map=folium.Map(location=[16.7283288158222376, 80.47967940849293],tiles='cartodbpositron',zoom_start=8,zoom_en=14)
coordinates_1=[[16.796244568792915, 80.84772587775123],[16.675253323388027, 80.9466028256286],[17.04849920972444, 81.81452273759137],
               [17.358095783991743, 82.55060668290068],[17.69333883439781, 83.02301876720367],[18.069740177657906, 83.51740350659053],
               [18.304583122186198, 83.85797966039033],[18.60680002716965, 84.23700796058692],[18.8617040197468, 84.47870716650938]]
coordinates_2=[[16.796244568792915, 80.84772587775123],[16.775208128370057, 80.87519172605109],[16.727867644052633, 80.99329474712684],
               [16.675253323388027, 80.9466028256286],[17.04849920972444, 81.81452273759137],[17.358095783991743, 82.55060668290068],
               [17.69333883439781, 83.02301876720367],[18.069740177657906, 83.51740350659053],[18.304583122186198, 83.85797966039033],
               [18.60680002716965, 84.23700796058692],[18.8617040197468, 84.47870716650938]]
        

              
#creating feature groups

f1=folium.FeatureGroup("path1")
f2=folium.FeatureGroup("path2")
folium.Marker(location=[16.796244568792915, 80.84772587775123],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='blue',prefix='glyphicon',icon='off')).add_to(map)
folium.Marker(location=[17.04849920972444, 81.81452273759137],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=folium.Icon(color='purple',prefix='fa',icon='ambulance')).add_to(map)
folium.Marker(location=[16.796244568792915, 80.84772587775123],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='green',prefix='fa',icon='gasstation')).add_to(map)
folium.Marker(location=[17.358095783991743, 82.55060668290068],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=folium.Icon(color='voilet',prefix='fa',icon='anchor')).add_to(map)
folium.Marker(location=[17.04849920972444, 81.81452273759137],popup='Default popup Marker1',tooltip='Click here to see more details',icon=folium.Icon(color='red',icon='none')).add_to(map)
folium.Marker(location=[17.358095783991743, 82.55060668290068],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='blue',prefix='fa',icon='Golfing')).add_to(map)
folium.Marker(location=[17.69333883439781, 83.02301876720367],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=folium.Icon(color='purple',prefix='fa',icon='hospital-o')).add_to(map)
folium.Marker(location=[18.069740177657906, 83.51740350659053],popup='Default popup Marker1',tooltip='Click here to see more details',icon=folium.Icon(color='red',icon='none')).add_to(map)
folium.Marker(location=[18.60680002716965, 84.23700796058692],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='blue',prefix='fa',icon='Airport')).add_to(map)
folium.Marker(location=[18.8617040197468, 84.47870716650938],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=folium.Icon(color='hotpink',prefix='fa',icon='ambulance')).add_to(map)


#adding lines to the different feature groups
line_1=folium.vector_layers.PolyLine(coordinates_1,popup='<b>path to palakol_1</b>',tooltip='path1',color='red',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(coordinates_2,popup='<b>path to palakol_2</b>',tooltip='path2',color='blue',weight=10).add_to(f2)
f1.add_to(map)
f2.add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: UserWarning: color argument of Icon should be one of: {'beige', 'gray', 'pink', 'darkpurple', 'lightgray', 'darkblue', 'darkred', 'purple', 'white', 'black', 'green', 'darkgreen', 'lightgreen', 'red', 'lightblue', 'cadetblue', 'lightred', 'orange', 'blue'}.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: UserWarning: color argument of Icon should be one of: {'beige', 'gray', 'pink', 'darkpurple', 'lightgray', 'darkblue', 'darkred', 'purple', 'white', 'black', 'green', 'darkgreen', 'lightgreen', 'red', 'lightblue', 'cadetblue', 'lightred', 'orange', 'blue'}.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
# ...
